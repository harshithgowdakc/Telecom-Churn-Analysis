# %% [markdown]
# <a href="https://colab.research.google.com/github/harshithgowdakc/Telecom-Churn-Analysis/blob/main/Telecom_Churn_Analysis_EDA_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ast

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
telecom_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AlmaBetter/Project CPG/Telecom Churn.csv')

# %%
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
telecom_df.shape
# Out:
# (3333, 20)

# %%
telecom_df.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
telecom_df.tail(5)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
telecom_df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
telecom_df.describe(include=[object])
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
telecom_df.describe(include= 'all')
# Out:
#        State  Account length    Area code International plan Voice mail plan  \
# count   3333     3333.000000  3333.000000               3333            3333
# unique    51             NaN          NaN                  2               2
# top       WV             NaN          NaN                 No              No
# freq     106             NaN          NaN               3010            2411
# mean     NaN      101.064806   437.182418                NaN             NaN
# std      NaN       39.822106    42.371290                NaN             NaN
# min      NaN        1.000000   408.000000                NaN             NaN
# 25%      NaN       74.000000   408.000000                NaN             NaN
# 50%      NaN      101.000000   415.000000                NaN             NaN
# 75%      NaN      127.000000   510.000000                NaN             NaN
# max      NaN      243.000000   510.000000                NaN             NaN
#
# ...

# %%
telecom_df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
telecom_df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
telecom_df.isna()
# Out:
#       State  Account length  Area code  International plan  Voice mail plan  \
# 0     False           False      False               False            False
# 1     False           False      False               False            False
# 2     False           False      False               False            False
# 3     False           False      False               False            False
# 4     False           False      False               False            False
# ...     ...             ...        ...                 ...              ...
# 3328  False           False      False               False            False
# 3329  False           False      False               False            False
# 3330  False           False      False               False            False
# 3331  False           False      False               False            False
# 3332  False           False      False               False            False
#
# ...

# %%
telecom_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Length: 3333, dtype: bool

# %%
telecom_df.loc[telecom_df.duplicated()].sum()
# Out:
# State                     0.0
# Account length            0.0
# Area code                 0.0
# International plan        0.0
# Voice mail plan           0.0
# Number vmail messages     0.0
# Total day minutes         0.0
# Total day calls           0.0
# Total day charge          0.0
# Total eve minutes         0.0
# Total eve calls           0.0
# Total eve charge          0.0
# Total night minutes       0.0
# Total night calls         0.0
# Total night charge        0.0
# Total intl minutes        0.0
# Total intl calls          0.0
# Total intl charge         0.0
# Customer service calls    0.0
# Churn                     0.0
# dtype: float64

# %%
telecom_df.duplicated(subset = ['State'])
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 3328     True
# 3329     True
# 3330     True
# 3331     True
# 3332     True
# Length: 3333, dtype: bool

# %%
telecom_df['State'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 3328     True
# 3329     True
# 3330     True
# 3331     True
# 3332     True
# Name: State, Length: 3333, dtype: bool

# %%
telecom_df[telecom_df["State"].duplicated()]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3       OH              84        408                Yes              No
# 14      IA              62        415                 No              No
# 24      VA             132        510                 No              No
# 27      MT              54        408                 No              No
# 28      MO              20        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
telecom_df.value_counts('Customer service calls')
# Out:
# Customer service calls
# 1    1181
# 2     759
# 0     697
# 3     429
# 4     166
# 5      66
# 6      22
# 7       9
# 8       2
# 9       2
# dtype: int64

# %%
telecom_df.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
telecom_df['Total day minutes'] = pd.to_datetime(telecom_df['Total day minutes'])
telecom_df['Total eve minutes'] = pd.to_datetime(telecom_df['Total eve minutes'])
telecom_df['Total night minutes'] = pd.to_datetime(telecom_df['Total night minutes'])
telecom_df['Total intl minutes'] = pd.to_datetime(telecom_df['Total intl minutes'])

# %%
x = telecom_df["Churn"].astype(int)

# %%
telecom_df["Churn"] = x

# %%
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   datetime64[ns]
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   datetime64[ns]
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   datetime64[ns]
#  13  Total night calls       3333 non-null   int64
# ...

# %%
telecom_df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages             Total day minutes  Total day calls  \
# 0                     25 1970-01-01 00:00:00.000000265              110
# 1                     26 1970-01-01 00:00:00.000000161              123
#
#    Total day charge             Total eve minutes  Total eve calls  \
# 0             45.07 1970-01-01 00:00:00.000000197               99
# 1             27.47 1970-01-01 00:00:00.000000195              103
#
#    Total eve charge           Total night minutes  Total night calls  \
# 0             16.78 1970-01-01 00:00:00.000000244                 91
# 1             16.62 1970-01-01 00:00:00.000000254                103
#
#    Total night charge            Total intl minutes  Total intl calls  \
# ...

# %%
x = telecom_df['State'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-6627380bbbca> in <module>
# ----> 1 x = telecom_df['State'].astype(int)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
x = telecom_df['State']

# %%
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   datetime64[ns]
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   datetime64[ns]
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   datetime64[ns]
#  13  Total night calls       3333 non-null   int64
# ...

# %%
plt.bar()

# %%
telecom_df['Customer service calls'].plot(kind = "kde", title = "top 5", color = "Blue" )
# Out:
# <AxesSubplot:title={'center':'top 5'}, ylabel='Density'>

# %%
telecom_df['Customer service calls'].value_counts().plot(kind = "bar", title = "top 5", color = "Blue" )
# Out:
# <AxesSubplot:title={'center':'top 5'}>

# %%
data = telecom_df['Customer service calls'],  telecom_df['Churn']

# %%
sns.heatmap(data, annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
telecom_df['State'].value_counts().head(5).plot(kind = "bar", title = "top 5" )

# %%
tt = telecom_df['Churn'].value_counts().plot(kind = "pie", title = "Total Churn customer")

# %%
telecom_df['Churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
telecom_df['Customer service calls'].plot(kind="hist", title = "customer review")

# %%
telecom_df['International plan'].value_counts().plot(kind="pie")

# %%
telecom_df['Customer service calls'].plot(kind="kde", title = "customer review")

# %%
telecom_df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
x = telecom_df['Churn'].astype(int)

# %%
telecom_df['Area code'].value_counts()
# Out:
# 415    1655
# 510     840
# 408     838
# Name: Area code, dtype: int64

# %%
telecom_df['Voice mail plan'].value_counts()
# Out:
# No     2411
# Yes     922
# Name: Voice mail plan, dtype: int64

# %%
x = telecom_df['Area code']
y = telecom_df['Churn']
sns.barplot(x,y)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
telecom_df['Account length'].value_counts()
# Out:
# 105    43
# 87     42
# 101    40
# 93     40
# 90     39
#        ..
# 243     1
# 200     1
# 232     1
# 5       1
# 221     1
# Name: Account length, Length: 212, dtype: int64

# %%
telecom_df['Area code'].value_counts()
# Out:
# 415    1655
# 510     840
# 408     838
# Name: Area code, dtype: int64

# %%
sns.pairplot(telecom_df, vars= ['Total day minutes','Total eve minutes','Total night minutes','Total intl minutes'])

# %%
x = telecom_df.plot(kind = 'scatter', x = 'State', y = 'Customer service calls')

# %%
sns.pairplot(telecom_df, vars= ['State','International plan','Customer service calls'])

# %%
telecom_df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages             Total day minutes  Total day calls  \
# 0                     25 1970-01-01 00:00:00.000000265              110
# 1                     26 1970-01-01 00:00:00.000000161              123
#
#    Total day charge             Total eve minutes  Total eve calls  \
# 0             45.07 1970-01-01 00:00:00.000000197               99
# 1             27.47 1970-01-01 00:00:00.000000195              103
#
#    Total eve charge           Total night minutes  Total night calls  \
# 0             16.78 1970-01-01 00:00:00.000000244                 91
# 1             16.62 1970-01-01 00:00:00.000000254                103
#
#    Total night charge            Total intl minutes  Total intl calls  \
# ...

# %%
sns.barplot(telecom_df['State'], telecom_df['Churn'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.distplot(telecom_df['Customer service calls'])

# %%
sns.countplot(telecom_df['State'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(telecom_df['Churn'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
